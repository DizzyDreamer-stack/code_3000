# %%
import pandas as pd
from mod06_deanonymize import load_data, link_records, deanonymization_rate

# %%
anon_path = "mod06_data/anonymized.csv"
aux_path = "mod06_data/auxiliary.csv"

# %% [markdown]
# ### Load and review the data

# %%
anon, aux = load_data(anon_path, aux_path)

# %%
anon.head(20)
# Out:
#    anon_id  age  zip3 gender
# 0    ERM5C   50   432      F
# 1    OFJJP   75   323      F
# 2    I3H24   44   323      M
# 3    3WUYW   66   323      M
# 4    ZN91P   18   323      M
# 5    7BLKV   36   606      F
# 6    4SJFH   70   890      M
# 7    0NO3L   31   110      M
# 8    U060Z   80   191      F
# 9    1761H   58   606      M
# 10   I9UI2   53   432      M
# 11   OO0ZT   47   941      F
# 12   BPEI7   19   112      M
# 13   ULMOZ   47   110      M
# 14   ES0E7   75   323      F
# 15   XCR1D   73   606      M
# 16   AY6JA   69   323      M
# 17   Q1J6V   40   941      F
# 18   BU6DU   54    62      F
# 19   LL1K7   69    21      M

# %% [markdown]
# ### Merge the datasets by age, gender, and zip3 and return the unique matches

# %%
matches = link_records(anon, aux)
matches.head()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 matches = link_records(anon, aux)
#       2 matches.head()
#
# File c:\Users\sarat\.vscode\code_3000-1\mod06_deanonymize.py:21, in link_records(anon_df, aux_df)
#      12 def link_records(anon_df, aux_df):
#      13     """
#      14     Attempt to link anonymized records to auxiliary records
#      15     using exact matching on quasi-identifiers.
#    (...)     19     containing ONLY uniquely matched records.
#      20     """
# ---> 21     com_cols = list(set(anon_df.columns)&set(aux_df.columns))
#      22     com_cols.remove('anon_id')
#      23     merge_df = pd.merge(
#      24         anon_df,
#      25         aux_df,
#    (...)     28         suffixes=('_anon', '_aux')
#      29     )
#
# NotImplementedError:

# %% [markdown]
# ### Calculate the match rate

# %%
rate = deanonymization_rate(matches, anon)
print(rate)

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Describe your reaction to the match rate. What sources of data might be prone to privacy issues?

# %% [markdown]
# Type your answer here. The sources

# %% [markdown]
# ### Provide examples of at least two other variables that could increase the match rate if included.

# %% [markdown]
# Type your answer here.
